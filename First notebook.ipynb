# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Azfar Hamidudin**
# Data Scientist

# %% [markdown]
# *I am interested in data science because of the variety of applications. It can be used to simplify processes in many industries saving large amounts of money.*

# %% [markdown]
# ## The code in the next cell will print a+b

# %%
a=1
b=2
print(a+b)
# Out:
# 3

# %% [markdown]
# | Syntax | Description |
# | ----------- | ----------- |
# | Header | Title |
# | Paragraph | Text |
#
#
# 1. First item
# 2. Second item
# 3. Third item
